# %%
import math
y = math.log2(40075017/611)
y
# Out:
# 16.001171226770396

# %%
m=40075017/(pow(2,16))
m
# Out:
# 611.4962310791016

# %%
m*3
# Out:
# 1834.4886932373047

# %%
from google.protobuf.json_format import MessageToDict
import pandas as pd
import math
import geopandas as gpd
from shapely.geometry import LineString, Point
import tomtomtrafficflowTile_pb2
import os
import matplotlib.pyplot as plt
import numpy as np
from utils_TomTom import *

# %%
# Valores globales
zoom_level = 16
tile = tomtomtrafficflowTile_pb2.Tile()
tiles_largo = 3
tiles_ancho = 3

# %%
df = pd.read_csv("C:/Users/valer/Documents/CIC/doctorado/air_pollution_data/traffic_EMCAS/traffic_SAC.csv")
df
# Out:
#            index        type  road_type  traffic_level traffic_road_coverage  \
# 0          66480  LINESTRING        NaN          0.178                  full
# 1          66481  LINESTRING        NaN          0.300                  full
# 2          66482  LINESTRING        NaN          0.341              one_side
# 3          66483  LINESTRING        NaN          0.445                  full
# 4          66484  LINESTRING        NaN          0.467                  full
# ...          ...         ...        ...            ...                   ...
# 207235  10682750  LINESTRING        NaN          1.000              one_side
# 207236  10682751  LINESTRING        NaN          1.000              one_side
# 207237  10682752  LINESTRING        NaN          1.000              one_side
# 207238  10682753  LINESTRING        NaN          1.000              one_side
# 207239  10682754  LINESTRING        NaN          1.000              one_side
#
#        road_closure road_category road_subcategory  left_hand_traffic  \
# 0               NaN       primary              NaN                NaN
# 1               NaN     secondary              NaN                NaN
# 2               NaN        street            local                NaN
# 3               NaN       primary              NaN                NaN
# 4               NaN       primary              NaN                NaN
# ...             ...           ...              ...                ...
# 207235          NaN        street            local                NaN
# 207236          NaN        street            local                NaN
# 207237          NaN        street            local                NaN
# 207238          NaN        street            local                NaN
# 207239          NaN        street            local                NaN
#
#                                               coordinates        date  \
# 0       [[19.348554187842513, -99.01866093277931], [19...  26-02-2024
# 1       [[19.352610894378618, -99.01560455560684], [19...  26-02-2024
# 2       [[19.349071715282708, -99.01610881090164], [19...  26-02-2024
# 3       [[19.351517633478057, -99.01648163795471], [19...  26-02-2024
# 4       [[19.352610894378618, -99.01474758982658], [19...  26-02-2024
# ...                                                   ...         ...
# 207235  [[19.34208681819203, -99.0087890625], [19.3420...  25-03-2024
# 207236  [[19.34208681819203, -99.0087890625], [19.3420...  25-03-2024
# 207237  [[19.342244996771797, -99.0078717470169], [19....  25-03-2024
# 207238  [[19.342244996771797, -99.0078717470169], [19....  25-03-2024
# 207239  [[19.337061801069954, -99.00530487298965], [19...  25-03-2024
#
#             time station  streetID
# 0       13:46:44     SAC    1763.0
# 1       13:46:44     SAC   19499.0
# 2       13:46:44     SAC   16689.0
# 3       13:46:44     SAC   18731.0
# 4       13:46:44     SAC   23935.0
# ...          ...     ...       ...
# 207235  02:11:13     SAC    7894.0
# 207236  02:11:13     SAC    7894.0
# 207237  02:11:13     SAC   19977.0
# 207238  02:11:13     SAC   19977.0
# 207239  02:11:13     SAC    8617.0
#
# [207240 rows x 14 columns]

# %%
a =df["road_category"].unique() 
a
# Out:
# array(['primary', 'secondary', 'street', 'tertiary'], dtype=object)

# %%
ruta_raiz = 'C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/vectores/' 
dataframes = []
all_points = []
# Itera sobre todas las carpetas y subcarpetas
for carpeta_actual, carpetas, archivos in os.walk(ruta_raiz):
    # Itera sobre todos los archivos en la carpeta actual
    for nombre_archivo in archivos:
        # Forma la ruta completa del archivo
        ruta_archivo = os.path.join(carpeta_actual, nombre_archivo)
        
        # Verifica si el archivo tiene una extensión específica (por ejemplo, .xlsx)
        if nombre_archivo.endswith('.pbf'):
            # Lee el archivo y agrega el DataFrame a la lista
            nombre = nombre_archivo.split("_")
            zoom_level = int(nombre[2])
            xTile = int(nombre[3])
            yTile = int(nombre[4])
            fecha = nombre[7]+"-"+nombre[6]+"-"+nombre[5]
            ultimo = nombre[10].split(".")
            hora = nombre[8]+":"+nombre[9]+":"+ultimo[0]
            estacion = nombre[0]
            df, points = conversion_vector(ruta_archivo, zoom_level, xTile, yTile, fecha, hora, estacion)
            if len(df)>0:
                dataframes.append(df)
                all_points.append(points)

# Combina todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, ignore_index=True)

# Muestra el DataFrame completo
df_completo
# Out:
#            type                                         properties  \
# 0    LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 1    LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 2    LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 3    LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 4    LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# ..          ...                                                ...
# 136  LINESTRING  [{'traffic_level': 0.7250000238418579}, {'traf...
# 137  LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 138  LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 139  LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 140  LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
#
#                                            coordinates        date      time  \
# 0    [(19.638972590153458, -98.9154052734375), (19....  10-04-2024  16:26:24
# 1    [(19.638972590153458, -98.9154052734375), (19....  10-04-2024  16:26:24
# 2    [(19.638526721815783, -98.91746118664742), (19...  10-04-2024  16:26:24
# 3    [(19.64258753401303, -98.91643792390823), (19....  10-04-2024  16:26:24
# 4    [(19.64258753401303, -98.91643792390823), (19....  10-04-2024  16:26:24
# ..                                                 ...         ...       ...
# 136  [(19.631708398231464, -98.9044189453125), (19....  10-04-2024  16:26:24
# 137  [(19.632240190483827, -98.90898808836937), (19...  10-04-2024  16:26:24
# 138  [(19.632240190483827, -98.90898808836937), (19...  10-04-2024  16:26:24
# 139  [(19.631337027869954, -98.909912109375), (19.6...  10-04-2024  16:26:24
# 140  [(19.632240190483827, -98.90737608075142), (19...  10-04-2024  16:26:24
#
#     station
# 0       ACO
# 1       ACO
# 2       ACO
# 3       ACO
# 4       ACO
# ..      ...
# 136     ACO
# 137     ACO
# 138     ACO
# 139     ACO
# 140     ACO
#
# [141 rows x 6 columns]

# %%
#ruta_raiz = 'C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/vectores/' 
ruta_raiz = "C:/Users/valer/Documents/CIC/doctorado/air_pollution_data/vectores/febrero/"
dataframes = []
all_points = []
# Itera sobre todas las carpetas y subcarpetas
for carpeta_actual, carpetas, archivos in os.walk(ruta_raiz):
    # Itera sobre todos los archivos en la carpeta actual
    for nombre_archivo in archivos:
        # Forma la ruta completa del archivo
        ruta_archivo = os.path.join(carpeta_actual, nombre_archivo)
        
        # Verifica si el archivo tiene una extensión específica (por ejemplo, .xlsx)
        if nombre_archivo.endswith('.pbf'):
            # Lee el archivo y agrega el DataFrame a la lista
            nombre = nombre_archivo.split("_")
            zoom_level = int(nombre[2])
            xTile = int(nombre[3])
            yTile = int(nombre[4])
            fecha = nombre[7]+"-"+nombre[6]+"-"+nombre[5]
            ultimo = nombre[10].split(".")
            hora = nombre[8]+":"+nombre[9]+":"+ultimo[0]
            estacion = nombre[0]
            dataframe, points = conversion_vectorDATAFRAME(ruta_archivo, zoom_level, xTile, yTile, fecha, hora, estacion)

            if len(dataframe)>0:
                dataframes.append(dataframe)
                all_points.append(points)

# Combina todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, ignore_index=True)

# Muestra el DataFrame completo
df_completo.to_csv("febrero.csv")

# %%
df_completo = []

# %%
#ruta_raiz = 'C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/vectores/' 
ruta_raiz = "C:/Users/valer/Documents/CIC/doctorado/air_pollution_data/vectores/marzo/"
dataframes = []
all_points = []
# Itera sobre todas las carpetas y subcarpetas
for carpeta_actual, carpetas, archivos in os.walk(ruta_raiz):
    # Itera sobre todos los archivos en la carpeta actual
    for nombre_archivo in archivos:
        # Forma la ruta completa del archivo
        ruta_archivo = os.path.join(carpeta_actual, nombre_archivo)
        
        # Verifica si el archivo tiene una extensión específica (por ejemplo, .xlsx)
        if nombre_archivo.endswith('.pbf'):
            # Lee el archivo y agrega el DataFrame a la lista
            nombre = nombre_archivo.split("_")
            zoom_level = int(nombre[2])
            xTile = int(nombre[3])
            yTile = int(nombre[4])
            fecha = nombre[7]+"-"+nombre[6]+"-"+nombre[5]
            ultimo = nombre[10].split(".")
            hora = nombre[8]+":"+nombre[9]+":"+ultimo[0]
            estacion = nombre[0]
            dataframe, points = conversion_vectorDATAFRAME(ruta_archivo, zoom_level, xTile, yTile, fecha, hora, estacion)

            if len(dataframe)>0:
                dataframes.append(dataframe)
                all_points.append(points)

# Combina todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, ignore_index=True)

# Muestra el DataFrame completo
df_completo.to_csv("marzo.csv")

# %%
df_completo = []

# %%
#ruta_raiz = 'C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/vectores/' 
ruta_raiz = "C:/Users/valer/Documents/CIC/doctorado/air_pollution_data/vectores/marzo2/"
dataframes = []
all_points = []
# Itera sobre todas las carpetas y subcarpetas
for carpeta_actual, carpetas, archivos in os.walk(ruta_raiz):
    # Itera sobre todos los archivos en la carpeta actual
    for nombre_archivo in archivos:
        # Forma la ruta completa del archivo
        ruta_archivo = os.path.join(carpeta_actual, nombre_archivo)
        
        # Verifica si el archivo tiene una extensión específica (por ejemplo, .xlsx)
        if nombre_archivo.endswith('.pbf'):
            # Lee el archivo y agrega el DataFrame a la lista
            nombre = nombre_archivo.split("_")
            zoom_level = int(nombre[2])
            xTile = int(nombre[3])
            yTile = int(nombre[4])
            fecha = nombre[7]+"-"+nombre[6]+"-"+nombre[5]
            ultimo = nombre[10].split(".")
            hora = nombre[8]+":"+nombre[9]+":"+ultimo[0]
            estacion = nombre[0]
            dataframe, points = conversion_vectorDATAFRAME(ruta_archivo, zoom_level, xTile, yTile, fecha, hora, estacion)

            if len(dataframe)>0:
                dataframes.append(dataframe)
                all_points.append(points)

# Combina todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, ignore_index=True)

# Muestra el DataFrame completo
df_completo.to_csv("marzo2.csv")

# %%
df_completo = []

# %%
#ruta_raiz = 'C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/vectores/' 
ruta_raiz = "C:/Users/valer/Documents/CIC/doctorado/air_pollution_data/vectores/abril/"
dataframes = []
all_points = []
# Itera sobre todas las carpetas y subcarpetas
for carpeta_actual, carpetas, archivos in os.walk(ruta_raiz):
    # Itera sobre todos los archivos en la carpeta actual
    for nombre_archivo in archivos:
        # Forma la ruta completa del archivo
        ruta_archivo = os.path.join(carpeta_actual, nombre_archivo)
        
        # Verifica si el archivo tiene una extensión específica (por ejemplo, .xlsx)
        if nombre_archivo.endswith('.pbf'):
            # Lee el archivo y agrega el DataFrame a la lista
            nombre = nombre_archivo.split("_")
            zoom_level = int(nombre[2])
            xTile = int(nombre[3])
            yTile = int(nombre[4])
            fecha = nombre[7]+"-"+nombre[6]+"-"+nombre[5]
            ultimo = nombre[10].split(".")
            hora = nombre[8]+":"+nombre[9]+":"+ultimo[0]
            estacion = nombre[0]
            dataframe, points = conversion_vectorDATAFRAME(ruta_archivo, zoom_level, xTile, yTile, fecha, hora, estacion)

            if len(dataframe)>0:
                dataframes.append(dataframe)
                all_points.append(points)

# Combina todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, ignore_index=True)

# Muestra el DataFrame completo
df_completo.to_csv("abril.csv")

# %%
df_completo = []

# %%
#ruta_raiz = 'C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/vectores/' 
ruta_raiz = "C:/Users/valer/Documents/CIC/doctorado/air_pollution_data/vectores/mayo/"
dataframes = []
all_points = []
# Itera sobre todas las carpetas y subcarpetas
for carpeta_actual, carpetas, archivos in os.walk(ruta_raiz):
    # Itera sobre todos los archivos en la carpeta actual
    for nombre_archivo in archivos:
        # Forma la ruta completa del archivo
        ruta_archivo = os.path.join(carpeta_actual, nombre_archivo)
        
        # Verifica si el archivo tiene una extensión específica (por ejemplo, .xlsx)
        if nombre_archivo.endswith('.pbf'):
            # Lee el archivo y agrega el DataFrame a la lista
            nombre = nombre_archivo.split("_")
            zoom_level = int(nombre[2])
            xTile = int(nombre[3])
            yTile = int(nombre[4])
            fecha = nombre[7]+"-"+nombre[6]+"-"+nombre[5]
            ultimo = nombre[10].split(".")
            hora = nombre[8]+":"+nombre[9]+":"+ultimo[0]
            estacion = nombre[0]
            dataframe, points = conversion_vectorDATAFRAME(ruta_archivo, zoom_level, xTile, yTile, fecha, hora, estacion)

            if len(dataframe)>0:
                dataframes.append(dataframe)
                all_points.append(points)

# Combina todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, ignore_index=True)

# %%
# Muestra el DataFrame completo
df_completo.to_csv("mayo.csv")

# %%
ruta_raiz = "C:/Users/valer/Documents/CIC/doctorado/air_pollution_data/vectores/mayo2/"
dataframes = []
all_points = []
# Itera sobre todas las carpetas y subcarpetas
for carpeta_actual, carpetas, archivos in os.walk(ruta_raiz):
    # Itera sobre todos los archivos en la carpeta actual
    for nombre_archivo in archivos:
        # Forma la ruta completa del archivo
        ruta_archivo = os.path.join(carpeta_actual, nombre_archivo)
        
        # Verifica si el archivo tiene una extensión específica (por ejemplo, .xlsx)
        if nombre_archivo.endswith('.pbf'):
            # Lee el archivo y agrega el DataFrame a la lista
            nombre = nombre_archivo.split("_")
            zoom_level = int(nombre[2])
            xTile = int(nombre[3])
            yTile = int(nombre[4])
            fecha = nombre[7]+"-"+nombre[6]+"-"+nombre[5]
            ultimo = nombre[10].split(".")
            hora = nombre[8]+":"+nombre[9]+":"+ultimo[0]
            estacion = nombre[0]
            dataframe, points = conversion_vectorDATAFRAME(ruta_archivo, zoom_level, xTile, yTile, fecha, hora, estacion)

            if len(dataframe)>0:
                dataframes.append(dataframe)
                all_points.append(points)

# Combina todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, ignore_index=True)

# Muestra el DataFrame completo
df_completo.to_csv("mayo2.csv")

# %%
ruta_raiz = "C:/Users/valer/Documents/CIC/doctorado/air_pollution_data/vectores/mayo3/"
dataframes = []
all_points = []
# Itera sobre todas las carpetas y subcarpetas
for carpeta_actual, carpetas, archivos in os.walk(ruta_raiz):
    # Itera sobre todos los archivos en la carpeta actual
    for nombre_archivo in archivos:
        # Forma la ruta completa del archivo
        ruta_archivo = os.path.join(carpeta_actual, nombre_archivo)
        
        # Verifica si el archivo tiene una extensión específica (por ejemplo, .xlsx)
        if nombre_archivo.endswith('.pbf'):
            # Lee el archivo y agrega el DataFrame a la lista
            nombre = nombre_archivo.split("_")
            zoom_level = int(nombre[2])
            xTile = int(nombre[3])
            yTile = int(nombre[4])
            fecha = nombre[7]+"-"+nombre[6]+"-"+nombre[5]
            ultimo = nombre[10].split(".")
            hora = nombre[8]+":"+nombre[9]+":"+ultimo[0]
            estacion = nombre[0]
            dataframe, points = conversion_vectorDATAFRAME(ruta_archivo, zoom_level, xTile, yTile, fecha, hora, estacion)

            if len(dataframe)>0:
                dataframes.append(dataframe)
                all_points.append(points)

# Combina todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, ignore_index=True)

# Muestra el DataFrame completo
df_completo.to_csv("mayo3.csv")

# %%
ruta_raiz = "C:/Users/valer/Documents/CIC/doctorado/air_pollution_data/vectores/mayo4/"
dataframes = []
all_points = []
# Itera sobre todas las carpetas y subcarpetas
for carpeta_actual, carpetas, archivos in os.walk(ruta_raiz):
    # Itera sobre todos los archivos en la carpeta actual
    for nombre_archivo in archivos:
        # Forma la ruta completa del archivo
        ruta_archivo = os.path.join(carpeta_actual, nombre_archivo)
        
        # Verifica si el archivo tiene una extensión específica (por ejemplo, .xlsx)
        if nombre_archivo.endswith('.pbf'):
            # Lee el archivo y agrega el DataFrame a la lista
            nombre = nombre_archivo.split("_")
            zoom_level = int(nombre[2])
            xTile = int(nombre[3])
            yTile = int(nombre[4])
            fecha = nombre[7]+"-"+nombre[6]+"-"+nombre[5]
            ultimo = nombre[10].split(".")
            hora = nombre[8]+":"+nombre[9]+":"+ultimo[0]
            estacion = nombre[0]
            try:
                dataframe, points = conversion_vectorDATAFRAME(ruta_archivo, zoom_level, xTile, yTile, fecha, hora, estacion)
            except:
                print(nombre)
            if len(dataframe)>0:
                dataframes.append(dataframe)
                all_points.append(points)

# Combina todos los DataFrames en uno solo
df_completo = pd.concat(dataframes, ignore_index=True)

# Muestra el DataFrame completo
df_completo.to_csv("mayo4.csv")
# Out:
# ['NEZ', '4', '16', '14740', '29168', '2024', '05', '31', '22', '01', '41.pbf']
# ['PED', '0', '16', '14707', '29180', '2024', '05', '31', '22', '01', '48.pbf']
# ['PED', '1', '16', '14708', '29180', '2024', '05', '31', '22', '01', '48.pbf']

# %%
nombre
# Out:
# ['NEZ', '4', '16', '14740', '29168', '2024', '05', '31', '22', '01', '41.pbf']

# %%
dir4 = "C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/mayo4.csv"
dir3 = "C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/mayo3.csv"
dir2 = "C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/mayo2.csv"
dir1 = "C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/mayo.csv"
df1 = pd.read_csv(dir1)
df2 = pd.read_csv(dir2)
df3 = pd.read_csv(dir3)
df4 = pd.read_csv(dir4)

df_completo= [df1, df2, df3, df4]

# %%
df_old = pd.read_csv("df_completo_07_abr_24_15153978_rows.csv") #15153978 rows × 13 columns
df_old
# Out:
#                 type  road_type  traffic_level traffic_road_coverage  \
# 0         LINESTRING        NaN            1.0                  full
# 1         LINESTRING        NaN            1.0                  full
# 2         LINESTRING        NaN            1.0                  full
# 3         LINESTRING        NaN            1.0              one_side
# 4         LINESTRING        NaN            1.0              one_side
# ...              ...        ...            ...                   ...
# 15153973  LINESTRING        NaN            1.0              one_side
# 15153974  LINESTRING        NaN            1.0              one_side
# 15153975  LINESTRING        NaN            1.0              one_side
# 15153976  LINESTRING        NaN            1.0              one_side
# 15153977  LINESTRING        NaN            1.0              one_side
#
#          road_closure road_category road_subcategory  left_hand_traffic  \
# 0                 NaN        street            local                NaN
# 1                 NaN        street            local                NaN
# 2                 NaN        street            local                NaN
# 3                 NaN        street            local                NaN
# 4                 NaN        street            local                NaN
# ...               ...           ...              ...                ...
# 15153973          NaN        street            local                NaN
# 15153974          NaN        street            local                NaN
# 15153975          NaN      tertiary      major_local                NaN
# 15153976          NaN      tertiary      major_local                NaN
# 15153977          NaN      tertiary      major_local                NaN
#
#                                                 coordinates        date  \
# 0         [[19.325524613420782, -99.20654296875], [19.32...  20-02-2024
# 1         [[19.32602544853046, -99.20379638671875], [19....  20-02-2024
# 2         [[19.32669491605546, -99.20331090688705], [19....  20-02-2024
# 3         [[19.325925154955115, -99.20242309570312], [19...  20-02-2024
# 4         [[19.325925154955115, -99.20242309570312], [19...  20-02-2024
# ...                                                     ...         ...
# 15153973  [[19.521836356785332, -99.085693359375], [19.5...  07-04-2024
# 15153974  [[19.52333295275669, -99.08347114920616], [19....  07-04-2024
# 15153975  [[19.52355289169167, -99.07916218042374], [19....  07-04-2024
# 15153976  [[19.52355289169167, -99.07916218042374], [19....  07-04-2024
# 15153977  [[19.521723859284105, -99.07470703125], [19.52...  07-04-2024
#
#               time station
# 0         18:50:21     PED
# 1         18:50:21     PED
# 2         18:50:21     PED
# 3         18:50:21     PED
# 4         18:50:21     PED
# ...            ...     ...
# 15153973  09:07:37     XAL
# 15153974  09:07:37     XAL
# 15153975  09:07:37     XAL
# 15153976  09:07:37     XAL
# 15153977  09:07:37     XAL
#
# [15153978 rows x 12 columns]

# %%
df_completo = [df_old, df1, df2, df3, df4]
df_concatenado = pd.concat(df_completo)
print(len(df_concatenado))
# Out:
# 25114034

# %%
df_concatenado
# Out:
#            type  road_type  traffic_level traffic_road_coverage road_closure  \
# 0    LINESTRING        NaN            1.0                  full          NaN
# 1    LINESTRING        NaN            1.0                  full          NaN
# 2    LINESTRING        NaN            1.0                  full          NaN
# 3    LINESTRING        NaN            1.0              one_side          NaN
# 4    LINESTRING        NaN            1.0              one_side          NaN
# ..          ...        ...            ...                   ...          ...
# 180  LINESTRING        NaN            1.0              one_side          NaN
# 181  LINESTRING        NaN            1.0              one_side          NaN
# 182  LINESTRING        NaN            1.0              one_side          NaN
# 183  LINESTRING        NaN            1.0              one_side          NaN
# 184  LINESTRING        NaN            1.0              one_side          NaN
#
#     road_category road_subcategory  left_hand_traffic  \
# 0          street            local                NaN
# 1          street            local                NaN
# 2          street            local                NaN
# 3          street            local                NaN
# 4          street            local                NaN
# ..            ...              ...                ...
# 180        street            local                NaN
# 181        street            local                NaN
# 182        street      minor_local                NaN
# 183        street      minor_local                NaN
# 184        street      minor_local                NaN
#
#                                            coordinates        date      time  \
# 0    [[19.325524613420782, -99.20654296875], [19.32...  20-02-2024  18:50:21
# 1    [[19.32602544853046, -99.20379638671875], [19....  20-02-2024  18:50:21
# 2    [[19.32669491605546, -99.20331090688705], [19....  20-02-2024  18:50:21
# 3    [[19.325925154955115, -99.20242309570312], [19...  20-02-2024  18:50:21
# 4    [[19.325925154955115, -99.20242309570312], [19...  20-02-2024  18:50:21
# ..                                                 ...         ...       ...
# 180  [[19.386085489623024, -99.019775390625], [19.3...  31-05-2024  22:01:41
# 181  [[19.388729478965598, -99.0252685546875], [19....  31-05-2024  22:01:41
# 182  [[19.385178436819857, -99.0252685546875], [19....  31-05-2024  22:01:41
# 183  [[19.385178436819857, -99.0252685546875], [19....  31-05-2024  22:01:41
# 184  [[19.385735066155135, -99.02489170432091], [19...  31-05-2024  22:01:41
#
#     station  Unnamed: 0
# 0       PED         NaN
# 1       PED         NaN
# 2       PED         NaN
# 3       PED         NaN
# 4       PED         NaN
# ..      ...         ...
# 180     NEZ       180.0
# 181     NEZ       181.0
# 182     NEZ       182.0
# 183     NEZ       183.0
# 184     NEZ       184.0
#
# [25114034 rows x 13 columns]

# %%
#del df_concatenado["Unnamed: 0.1"]
del df_concatenado["Unnamed: 0"]
df_concatenado.to_csv("df_completo_31_mayo_24_25114034_rows.csv", index=False) #15153978 rows × 13 columns

# %%
dir3 = "C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/marzo3.csv"
dir2 = "C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/marzo2.csv"
dir1 = "C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/marzo.csv"
dir0 = "C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/febrero.csv"
dir = "C:/Users/valer/Documents/CIC/doctorado/air_pollution/traffic_flow/vector/abril.csv"

df3 = pd.read_csv(dir3)
df2 = pd.read_csv(dir2)
df1 = pd.read_csv(dir1)
df0 = pd.read_csv(dir0)
df = pd.read_csv(dir)

df_completo= [df0, df1, df2, df3, df]

# %%
df_concatenado = pd.concat(df_completo)

# %%
len(df_concatenado)
# Out:
# 15153978

# %%
del df_concatenado["Unnamed: 0.1"]
del df_concatenado["Unnamed: 0"]

# %%
df_concatenado.to_csv("df_completo_07_abr_24_15153978_rows.csv") #15153978 rows × 13 columns

# %%
df_completo.to_csv("df_completo_03_abr_24_10322288_rows.csv")

# %%
"""
# Crear una nueva figura
plt.figure()
limites = [0, 0.15, 0.35, 0.75, float('inf')]
colores = ['#777777', '#FF2323', '#FFFF37', '#2BC82B']
for i in range(len(all_points)):
    latitudes, longitudes = zip(*all_points[i][0]["coordinates"])
    velocidades = all_points[i][0]["properties"][0]["traffic_level"]
    # Mapear las velocidades a los índices de colores
    indices_colores = np.digitize(velocidades, bins=limites, right=True)
    # Graficar las coordenadas en la misma figura
    plt.plot(longitudes, latitudes, color=colores[indices_colores-1], marker='o', linestyle='-')
# Personalizar la apariencia del gráfico
plt.title('Ubicación de Coordenadas en la Calle')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()
"""

# %%
#Para linestring las coordenadas deben tener el orden longitude,latitude
dir_geojson = "geojsons"
stations = df_completo["station"].unique()
for station in stations:        
        values = []
        lines = []
        coverages = []
        fechas = []
        horas = []
        station_name = []
        df = df_completo[df_completo["station"]==station]
        for i in range(0,len(df)):
                values.append(df.iloc[i]["properties"][0]["traffic_level"])
                lines.append(LineString(df.iloc[i]["coordinates"]))
                coverages.append(df.iloc[i]["properties"][1]['traffic_road_coverage'])
                fechas.append(df.iloc[i]["date"])
                horas.append(df.iloc[i]["time"])
                station_name.append(station)

        # Crear un DataFrame de ejemplo con coordenadas y valores
        data = {"traffic_level": values,
                "roadCovrag": coverages,
                "date": fechas,
                "time": horas,
                "Coordinate": lines,
                "station": station_name}

        df = pd.DataFrame(data)

        # Convertir DataFrame a GeoDataFrame
        gdf = gpd.GeoDataFrame(df, geometry='Coordinate')

        name_geojson = "datos_trafico_"+station+'.geojson'
        ruta = os.path.join(dir_geojson,name_geojson)
        # Guardar el GeoDataFrame en un archivo GeoJSON o Shapefile
        gdf.to_file(ruta, driver='GeoJSON')

# %%
# Crear GeoJson con todos los datos
#Para linestring las coordenadas deben tener el orden longitude,latitude
 
values = []
lines = []
coverages = []
fechas = []
horas = []
for i in range(0,len(df_completo)):
    values.append(df_completo.iloc[i]["properties"][0]["traffic_level"])
    lines.append(LineString(df_completo.iloc[i]["coordinates"]))
    coverages.append(df_completo.iloc[i]["properties"][1]['traffic_road_coverage'])
    fechas.append(df_completo.iloc[i]["date"])
    horas.append(df_completo.iloc[i]["time"])

# Crear un DataFrame de ejemplo con coordenadas y valores
data = {"traffic_level": values,
        "roadCovrag": coverages,
        "date": fechas,
        "time": horas,
        "Coordinate": lines}

df = pd.DataFrame(data)

# Convertir DataFrame a GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry='Coordinate')

name_geojson = "all_traffic_data_"+'.geojson'
# Guardar el GeoDataFrame en un archivo GeoJSON o Shapefile
gdf.to_file(name_geojson , driver='GeoJSON')

# %%
#Graficar tiles de un día y hora específico
"""
# Crear una nueva figura
plt.figure()

limites = [0, 0.15, 0.35, 0.75, float('inf')]
colores = ['#777777', '#FF2323', '#FFFF37', '#2BC82B']

for i in range(len(all_points)):
    for j in range(len(all_points[i])):
        if all_points[i][j]["date"]=='27-02-2024' and all_points[i][j]["time"]=="13:31:09":
            latitudes, longitudes = zip(*all_points[i][j]["coordinates"])
            velocidades = all_points[i][j]["properties"][0]["traffic_level"]
            # Mapear las velocidades a los índices de colores
            indices_colores = np.digitize(velocidades, bins=limites, right=True)
            # Graficar las coordenadas en la misma figura
            plt.plot(latitudes, longitudes, color=colores[indices_colores-1], marker='o', linestyle='-')


# Personalizar la apariencia del gráfico
plt.title('Ubicación de Coordenadas en la Calle')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()
"""

# %%
# Puntos con  las coordenadas bien, solo hay que cambiar la funcion "transform" para que las coordenadas las regrese con el orden lat, lon
"""
values = []
lines = []
coverages = []
fechas = []
horas = []
for i in range(0,len(all_points)):
    for lat, lon in all_points[i][0]["coordinates"]:
        values.append(all_points[i][0]["properties"][0]["traffic_level"])
        lines.append(Point(lon, lat))
        coverages.append(all_points[i][0]["properties"][1]['traffic_road_coverage'])
        fechas.append(all_points[i][0]["date"])
        horas.append(all_points[i][0]["time"])

# Crear un DataFrame de ejemplo con coordenadas y valores
data = {'traffic_level': values,
        "roadCovrag": coverages,
        "date": fechas,
        "time": horas,
        'geometry': lines}

df = pd.DataFrame(data)

# Convertir DataFrame a GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry='geometry', crs=4326)

ruta_geojson = 'conjuntos_coordenadas.geojson'
# Guardar el GeoDataFrame en un archivo GeoJSON o Shapefile
gdf.to_file(ruta_geojson, driver='GeoJSON')
"""

# %%
import geopandas as gpd

# Ruta al archivo GeoJSON
ruta_geojson = 'geojsons/datos_trafico_MER.geojson'

# Leer el archivo GeoJSON
datos_geojson = gpd.read_file(ruta_geojson)

# Mostrar los datos leídos
datos_geojson
# Out:
#        traffic_level roadCovrag        date      time station  \
# 0              0.223       full  23-02-2024  13:56:17     MER
# 1              0.252       full  23-02-2024  13:56:17     MER
# 2              0.252       full  23-02-2024  13:56:17     MER
# 3              0.300       full  23-02-2024  13:56:17     MER
# 4              0.300       full  23-02-2024  13:56:17     MER
# ...              ...        ...         ...       ...     ...
# 19274          1.000   one_side  27-02-2024  23:03:08     MER
# 19275          1.000   one_side  27-02-2024  23:03:08     MER
# 19276          1.000   one_side  27-02-2024  23:03:08     MER
# 19277          1.000   one_side  27-02-2024  23:03:08     MER
# 19278          1.000   one_side  27-02-2024  23:03:08     MER
#
#                                                 geometry
# 0      LINESTRING (-99.12668 19.42515, -99.12671 19.4...
# 1      LINESTRING (-99.12921 19.43033, -99.12826 19.4...
# 2      LINESTRING (-99.12887 19.42603, -99.12863 19.4...
# 3      LINESTRING (-99.12509 19.42915, -99.12516 19.4...
# 4      LINESTRING (-99.12509 19.42915, -99.12516 19.4...
# ...                                                  ...
# 19274  LINESTRING (-99.11316 19.41508, -99.11353 19.4...
# 19275  LINESTRING (-99.11565 19.41533, -99.11556 19.4...
# 19276  LINESTRING (-99.11527 19.41740, -99.11411 19.4...
# 19277  LINESTRING (-99.11527 19.41740, -99.11411 19.4...
# 19278  LINESTRING (-99.11316 19.41723, -99.11326 19.4...
#
# [19279 rows x 6 columns]

# %%
import pandas as pd

# Cargar los DataFrames desde los archivos CSV
df1 = pd.read_csv("df_completo_03_abr_24_10322288_rows.csv")
df2 = pd.read_csv("df_completo_2_rows.csv")

# Unir los DataFrames
df_union = pd.concat([df1, df2], ignore_index=True)

# Si deseas unir los DataFrames basados en una columna común, puedes usar la función merge
# Por ejemplo, si ambos DataFrames tienen una columna 'ID' en común
# df_union = pd.merge(df1, df2, on='ID')

# Guardar el DataFrame resultante en un nuevo archivo CSV
#df_union.to_csv('union.csv', index=False)

# %%
df_union
# Out:
#           Unnamed: 0        type  \
# 0                  0  LINESTRING
# 1                  1  LINESTRING
# 2                  2  LINESTRING
# 3                  3  LINESTRING
# 4                  4  LINESTRING
# ...              ...         ...
# 15155046     4832758  LINESTRING
# 15155047     4832759  LINESTRING
# 15155048     4832760  LINESTRING
# 15155049     4832761  LINESTRING
# 15155050     4832762  LINESTRING
#
#                                                  properties  \
# 0         [{'traffic_level': 1.0}, {'traffic_road_covera...
# 1         [{'traffic_level': 1.0}, {'traffic_road_covera...
# 2         [{'traffic_level': 1.0}, {'traffic_road_covera...
# 3         [{'traffic_level': 1.0}, {'traffic_road_covera...
# 4         [{'traffic_level': 1.0}, {'traffic_road_covera...
# ...                                                     ...
# 15155046  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 15155047  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 15155048  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 15155049  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 15155050  [{'traffic_level': 1.0}, {'traffic_road_covera...
#
#                                                 coordinates        date  \
# 0         [(-99.20654296875, 19.325524613420782), (-99.2...  20-02-2024
# 1         [(-99.20379638671875, 19.32602544853046), (-99...  20-02-2024
# 2         [(-99.20331090688705, 19.32669491605546), (-99...  20-02-2024
# 3         [(-99.20242309570312, 19.325925154955115), (-9...  20-02-2024
# 4         [(-99.20242309570312, 19.325925154955115), (-9...  20-02-2024
# ...                                                     ...         ...
# 15155046  [(-99.08388823270798, 19.521718803216636), (-9...  31-03-2024
# 15155047  [(-99.08347114920616, 19.52333295275669), (-99...  31-03-2024
# 15155048  [(-99.07916218042374, 19.52355289169167), (-99...  31-03-2024
# 15155049  [(-99.07916218042374, 19.52355289169167), (-99...  31-03-2024
# 15155050  [(-99.07470703125, 19.521723859284105), (-99.0...  31-03-2024
#
#               time station
# 0         18:50:21     PED
# 1         18:50:21     PED
# 2         18:50:21     PED
# 3         18:50:21     PED
# 4         18:50:21     PED
# ...            ...     ...
# 15155046  09:06:47     XAL
# 15155047  09:06:47     XAL
# 15155048  09:06:47     XAL
# 15155049  09:06:47     XAL
# 15155050  09:06:47     XAL
#
# [15155051 rows x 7 columns]

# %%
df_union = df_union.reset_index(drop=True)
df_union
# Out:
#           Unnamed: 0        type  \
# 0                  0  LINESTRING
# 1                  1  LINESTRING
# 2                  2  LINESTRING
# 3                  3  LINESTRING
# 4                  4  LINESTRING
# ...              ...         ...
# 15155046     4832758  LINESTRING
# 15155047     4832759  LINESTRING
# 15155048     4832760  LINESTRING
# 15155049     4832761  LINESTRING
# 15155050     4832762  LINESTRING
#
#                                                  properties  \
# 0         [{'traffic_level': 1.0}, {'traffic_road_covera...
# 1         [{'traffic_level': 1.0}, {'traffic_road_covera...
# 2         [{'traffic_level': 1.0}, {'traffic_road_covera...
# 3         [{'traffic_level': 1.0}, {'traffic_road_covera...
# 4         [{'traffic_level': 1.0}, {'traffic_road_covera...
# ...                                                     ...
# 15155046  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 15155047  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 15155048  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 15155049  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 15155050  [{'traffic_level': 1.0}, {'traffic_road_covera...
#
#                                                 coordinates        date  \
# 0         [(-99.20654296875, 19.325524613420782), (-99.2...  20-02-2024
# 1         [(-99.20379638671875, 19.32602544853046), (-99...  20-02-2024
# 2         [(-99.20331090688705, 19.32669491605546), (-99...  20-02-2024
# 3         [(-99.20242309570312, 19.325925154955115), (-9...  20-02-2024
# 4         [(-99.20242309570312, 19.325925154955115), (-9...  20-02-2024
# ...                                                     ...         ...
# 15155046  [(-99.08388823270798, 19.521718803216636), (-9...  31-03-2024
# 15155047  [(-99.08347114920616, 19.52333295275669), (-99...  31-03-2024
# 15155048  [(-99.07916218042374, 19.52355289169167), (-99...  31-03-2024
# 15155049  [(-99.07916218042374, 19.52355289169167), (-99...  31-03-2024
# 15155050  [(-99.07470703125, 19.521723859284105), (-99.0...  31-03-2024
#
#               time station
# 0         18:50:21     PED
# 1         18:50:21     PED
# 2         18:50:21     PED
# 3         18:50:21     PED
# 4         18:50:21     PED
# ...            ...     ...
# 15155046  09:06:47     XAL
# 15155047  09:06:47     XAL
# 15155048  09:06:47     XAL
# 15155049  09:06:47     XAL
# 15155050  09:06:47     XAL
#
# [15155051 rows x 7 columns]

# %%
del df_union["Unnamed: 0"]

# %%
df_union
# Out:
#                 type                                         properties  \
# 0         LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 1         LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 2         LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 3         LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 4         LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# ...              ...                                                ...
# 15155046  LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 15155047  LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 15155048  LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 15155049  LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
# 15155050  LINESTRING  [{'traffic_level': 1.0}, {'traffic_road_covera...
#
#                                                 coordinates        date  \
# 0         [(-99.20654296875, 19.325524613420782), (-99.2...  20-02-2024
# 1         [(-99.20379638671875, 19.32602544853046), (-99...  20-02-2024
# 2         [(-99.20331090688705, 19.32669491605546), (-99...  20-02-2024
# 3         [(-99.20242309570312, 19.325925154955115), (-9...  20-02-2024
# 4         [(-99.20242309570312, 19.325925154955115), (-9...  20-02-2024
# ...                                                     ...         ...
# 15155046  [(-99.08388823270798, 19.521718803216636), (-9...  31-03-2024
# 15155047  [(-99.08347114920616, 19.52333295275669), (-99...  31-03-2024
# 15155048  [(-99.07916218042374, 19.52355289169167), (-99...  31-03-2024
# 15155049  [(-99.07916218042374, 19.52355289169167), (-99...  31-03-2024
# 15155050  [(-99.07470703125, 19.521723859284105), (-99.0...  31-03-2024
#
#               time station
# 0         18:50:21     PED
# 1         18:50:21     PED
# 2         18:50:21     PED
# 3         18:50:21     PED
# 4         18:50:21     PED
# ...            ...     ...
# 15155046  09:06:47     XAL
# 15155047  09:06:47     XAL
# 15155048  09:06:47     XAL
# 15155049  09:06:47     XAL
# 15155050  09:06:47     XAL
#
# [15155051 rows x 6 columns]

# %%
df_union.to_csv("datos_al_07_abr_24_15155051_rows.csv")

# %%
"""
def tileZXYToLatLon(z, x, y):
    MAX_ZOOM_LEVEL = 22

    if z > MAX_ZOOM_LEVEL or (z is None or not isinstance(z, (int, float))):
        raise ValueError(f"Zoom level value is out of range [0, {MAX_ZOOM_LEVEL}]")
    minXY = 0
    maxXY = int(2**z - 1)
    if x > maxXY or x < minXY or x is None or not isinstance(x, (int, float)):
        raise ValueError(f"Tile x value is out of range [0, {maxXY}]")

    if y > maxXY or y < minXY or y is None or not isinstance(y, (int, float)):
        raise ValueError(f"Tile y value is out of range [0, {maxXY}]")

    
    lon = (x / (2**z)) * 360.0 - 180.0
    n = math.pi - (2.0 * math.pi * y) / (2**z)
    lat = (180.0 / math.pi) * (math.atan(0.5 * (math.exp(n) - math.exp(-n))))
   
    return lat,lon
"""
"""
# Función para convertir coordenadas geodésicas a coordenadas de tiles
def lat_lon_to_tile_zxy(lat, lon, zoom_level):
    
    min_zoom_level = 0
    max_zoom_level = 22
    min_lat = -85.051128779807
    max_lat = 85.051128779806
    min_lon = -180.0
    max_lon = 180.0

    # Check input values of zoom level, latitude and longitude
    if (zoom_level is None or not isinstance(zoom_level, (int, float))
        or zoom_level < min_zoom_level
        or zoom_level > max_zoom_level ):
        
        raise ValueError(
            f"Zoom level value is out of range [{min_zoom_level}, {max_zoom_level}]"
        )

    if lat is None or not isinstance(lat, (int, float)) or lat < min_lat or lat > max_lat:
        raise ValueError(f"Latitude value is out of range [{min_lat}, {max_lat}]")

    if (lon is None or not isinstance(lon, (int, float))
        or lon < min_lon
        or lon > max_lon ):
        
        raise ValueError(f"Longitude value is out of range [{min_lon}, {max_lon}]")

    z = int(zoom_level)
    xy_tiles_count = 2**z
    x = int(((lon + 180.0) / 360.0) * xy_tiles_count)
    y = int(((1.0 - math.log( math.tan((lat * math.pi) / 180.0) + 1.0 / math.cos((lat * math.pi) / 180.0)) /math.pi)/ 2.0)* xy_tiles_count)

    return x,y

def transform(decodedTiles, zoom_level, xTile, yTile):
    lat_inicio, lon_inicio = tileZXYToLatLon(zoom_level, xTile, yTile)
    lat_fin, lon_fin = tileZXYToLatLon(zoom_level, xTile+1, yTile+1)

    # Calcular diferencias en latitud y longitud
    diff_lat =lat_fin-lat_inicio
    diff_lon =lon_fin-lon_inicio

    num_pixeles = 4096
    coordinates = []

    # Calcular incrementos por píxel
    inc_lat = diff_lat / num_pixeles
    inc_lon = diff_lon / num_pixeles
    for x,y in decodedTiles:
        lat_pixel = lat_inicio + (y * inc_lat)
        lon_pixel = lon_inicio + (x * inc_lon)
        coordinates.append((lon_pixel,lat_pixel))
    return coordinates

def decode_geometry(geometry):
    c = 0
    decodeTiles = []
    lines =[]
    decode_x = 0
    decode_y = 0
    while c < len(geometry):
        command_and_count = geometry[c]
        command = command_and_count & 0x7
        count = command_and_count >> 0x3
        #print("comand",command)
        for _ in range(count):
            x = geometry[c+1] 
            y = geometry[c+2]
            decode_x += ((x >> 0x1) ^ (-(x & 0x1))) 
            decode_y += ((y >> 0x1) ^ (-(y & 0x1)))
            if command==1:
                if len(decodeTiles)==0:
                    decodeTiles.append([decode_x, decode_y])    
                else:
                    lines.append(decodeTiles) 
                    decodeTiles = []  
                    decodeTiles.append([decode_x, decode_y])    
            elif command==2:     
                decodeTiles.append([decode_x, decode_y])         
            c += 2
        if command==2:
            lines.append(decodeTiles) 
        c += 1        
        #c += 3
    #return  decodeTiles
    return lines


#Para guardarlo como puntos Point debe ser lat, lon
#Si se guardan como líneas linestring, debe ser lon, lat
def conversion_vector(ruta_archivo, zoom_level, xTile, yTile, fecha, hora, estacion):
  #conversion vector a dataframe
  with open(ruta_archivo, "rb") as f:
    tile.ParseFromString(f.read())
  dict_request = MessageToDict(tile)
  points = []
  dictionary ={}
  if "layers" in dict_request.keys():
    if dict_request['layers'][0]['name'] == 'Traffic flow':
      keys = dict_request['layers'][0]["keys"]
      values = dict_request['layers'][0]["values"]
      for line in dict_request['layers'][0]["features"]:
          all_properties = []
          if line["type"]=="LINESTRING":	
            geometry = line["geometry"]
            lines = decode_geometry(geometry)
            for decodedLines in lines:
                coordinates = transform(decodedLines, zoom_level, xTile, yTile)
                if len(coordinates)>0:
                    tags = line["tags"]
                    all_properties = []
                    for i in range(0, int(len(tags)/2), 2):
                        key = keys[tags[i]]
                        value = values[tags[i+1]]
                        value = value[list(value.keys())[0]]
                        properties = {key:value}
                        all_properties.append(properties)

                    dictionary = {"type": line["type"],
                                "properties": all_properties,
                                "coordinates": coordinates,
                                "date": fecha,
                                "time": hora,
                                "station": estacion}
                    points.append(dictionary)
      # Lista de nombres de columnas
      columnas = ['type', 'properties', 'coordinates',"date","time","station"]
      # Crear un DataFrame a partir de la lista y los nombres de columnas
      dataframe = pd.DataFrame(points, columns=columnas)
  else:
     dataframe = []
     points  = []
  return dataframe, points
"""
